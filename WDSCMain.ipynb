# %%
import pandas as pd
import numpy as np

# %%
import os

file = "whl_2025.xlsx"

# Check if file exists in current directory
if os.path.exists(file):
	pd.read_excel(file).describe()
else:
	print(f"File '{file}' not found in current directory: {os.getcwd()}")
	print("Available files:", os.listdir())
# Out:
# File 'whl_2025.xlsx' not found in current directory: c:\Users\PC\Desktop\Wharton Data Science Competition
# Available files: ['Data']
