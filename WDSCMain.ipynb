# %%
import pandas as pd
import numpy as np

# %%
file = "whl_2025.xlsx"

pd.read_excel(file).describe()
# Out:
#             went_ot           toi  home_assists    home_shots       home_xg  \
# count  25827.000000  25827.000000  25827.000000  25827.000000  25827.000000
# mean       0.210942    190.194902      0.245054      1.400240      0.158953
# std        0.407985    153.702230      0.798532      2.046256      0.305636
# min        0.000000      0.010000      0.000000      0.000000      0.000000
# 25%        0.000000     92.645000      0.000000      0.000000      0.000000
# 50%        0.000000    156.190000      0.000000      1.000000      0.089800
# 75%        0.000000    237.985000      0.000000      2.000000      0.187800
# max        1.000000   1559.670000     13.000000     28.000000      5.543500
#
#         home_max_xg    home_goals  away_assists    away_shots       away_xg  \
# count  25827.000000  25827.000000  25827.000000  25827.000000  25827.000000
# mean       0.066332      0.157045      0.211445      1.329113      0.142801
# ...
