# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import PoissonRegressor
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import math

# %%
def norm(s):
    return str(s).strip().lower().replace(" ", "_")

main_path = "League Table (2026).xlsx"
base = pd.read_excel(main_path, sheet_name="Base")
whl  = pd.read_excel(main_path, sheet_name="whl_2025")
sg   = pd.read_excel(main_path, sheet_name="saved_goals_ per_60_min")

# Rename goalie id 
sg = sg.rename(columns={sg.columns[0]: "goalie_id", sg.columns[-1]: "ga_minus_xga_per60"})
sg["goalie_id"] = sg["goalie_id"].astype(str).str.strip()
sg["ga_minus_xga_per60"] = pd.to_numeric(sg["ga_minus_xga_per60"], errors="coerce").fillna(0.0)

# Convert to "saved goals per 60" where positive = good
# saved60 = -(GA - xGA per 60)
sg["saved60"] = -sg["ga_minus_xga_per60"]
goalie_saved60 = sg.set_index("goalie_id")["saved60"]

#Build primary goalies per game from whl (max TOI goalie)
whl["game_id"] = whl["game_id"].astype(str).str.strip()
whl["home_goalie"] = whl["home_goalie"].astype(str).str.strip()
whl["away_goalie"] = whl["away_goalie"].astype(str).str.strip()

home_g = (whl.groupby(["game_id", "home_goalie"], as_index=False)["toi"].sum()
            .sort_values(["game_id", "toi"], ascending=[True, False])
            .drop_duplicates("game_id")
            .rename(columns={"home_goalie": "home_goalie_game"}))

away_g = (whl.groupby(["game_id", "away_goalie"], as_index=False)["toi"].sum()
            .sort_values(["game_id", "toi"], ascending=[True, False])
            .drop_duplicates("game_id")
            .rename(columns={"away_goalie": "away_goalie_game"}))

game_goalies = home_g.merge(away_g, on="game_id", how="inner")
game_goalies["home_goalie_saved60"] = game_goalies["home_goalie_game"].map(goalie_saved60).fillna(0.0)
game_goalies["away_goalie_saved60"] = game_goalies["away_goalie_game"].map(goalie_saved60).fillna(0.0)

# Merge goalie
base["game_id"] = base["game_id"].astype(str).str.strip()

base2 = base.merge(
    game_goalies[["game_id", "home_goalie_saved60", "away_goalie_saved60"]],
    on="game_id",
    how="left"
)
base2[["home_goalie_saved60", "away_goalie_saved60"]] = base2[["home_goalie_saved60", "away_goalie_saved60"]].fillna(0.0)

base2["home_team"] = base2["home_team"].map(norm)
base2["away_team"] = base2["away_team"].map(norm)

team_rows_home = pd.DataFrame({
    "team": base2["home_team"],
    "opp": base2["away_team"],
    "goals": base2["sum home_goals"].astype(int),
    "is_home": 1,
    "opp_goalie_saved60": base2["away_goalie_saved60"],  # opponent goalie
})

team_rows_away = pd.DataFrame({
    "team": base2["away_team"],
    "opp": base2["home_team"],
    "goals": base2["sum away_goals"].astype(int),
    "is_home": 0,
    "opp_goalie_saved60": base2["home_goalie_saved60"],  # opponent goalie
})

team_df = pd.concat([team_rows_home, team_rows_away], ignore_index=True)

def make_team_model(alpha=0.5):
    pre = ColumnTransformer([
        ("opp", OneHotEncoder(handle_unknown="ignore"), ["opp"]),
        ("num", "passthrough", ["is_home", "opp_goalie_saved60"]),
    ])
    return Pipeline([
        ("pre", pre),
        ("pois", PoissonRegressor(alpha=alpha, max_iter=10000))
    ])

teams = sorted(team_df["team"].unique())
team_models = {}

for t in teams:
    df_t = team_df[team_df["team"] == t]
    X_t = df_t[["opp", "is_home", "opp_goalie_saved60"]]
    y_t = df_t["goals"].values
    m = make_team_model(alpha=0.5)
    m.fit(X_t, y_t)
    team_models[t] = m

def predict_lambdas_teamwise(home_team, away_team):
    home_team = norm(home_team); away_team = norm(away_team)

    mh = team_models[home_team]
    ma = team_models[away_team]

    lam_h = float(mh.predict(pd.DataFrame([{
        "opp": away_team, "is_home": 1, "opp_goalie_saved60": 0.0
    }]))[0])

    lam_a = float(ma.predict(pd.DataFrame([{
        "opp": home_team, "is_home": 0, "opp_goalie_saved60": 0.0
    }]))[0])

    return lam_h, lam_a

# %%
def poisson_pmf(k, lam):
    return math.exp(-lam) * (lam**k) / math.factorial(k)

def plot_poisson_cdf(lam, k_max=10):
    ks = np.arange(0, k_max + 1)
    pmf = np.array([poisson_pmf(int(k), lam) for k in ks])
    cdf = np.cumsum(pmf)

    plt.figure()
    plt.step(ks, cdf, where="post")
    plt.xlabel("k")
    plt.ylabel("P(Goals ≤ k)")
    plt.title(f"Poisson CDF (λ = {lam:.2f})")
    plt.ylim(0, 1)
    plt.show()
    
lam_h = predict_lambdas_teamwise("mongolia", "thailand")[0]

plot_poisson_cdf(lam_h, k_max=10)

def plot_matchup_pmfs(lam_h, lam_a, k_max=5, home_name="Home", away_name="Away"):
    ks = np.arange(0, k_max + 1)
    ph = np.array([poisson_pmf(int(k), lam_h) for k in ks])
    pa = np.array([poisson_pmf(int(k), lam_a) for k in ks])

    plt.figure()
    width = 0.4
    plt.bar(ks - width/2, ph, width=width, label=f"{home_name} (λ={lam_h:.2f})")
    plt.bar(ks + width/2, pa, width=width, label=f"{away_name} (λ={lam_a:.2f})")
    plt.xlabel("Goals (k)")
    plt.ylabel("Probability")
    plt.title("Goal Distributions (Poisson)")
    plt.legend()
    plt.show()

plot_matchup_pmfs(*predict_lambdas_teamwise("mongolia", "thailand"), k_max=5, home_name="mongolia", away_name="thailand")
